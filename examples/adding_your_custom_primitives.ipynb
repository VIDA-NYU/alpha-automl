# %% [markdown]
# ## Adding Your Custom Primitive

# %% [markdown]
# First, import the class `AutoMLClassifier`

# %%
from alpha_automl import AutoMLClassifier
import pandas as pd

# %% [markdown]
# ### Generating Pipelines for CSV Datasets

# %% [markdown]
# In this example, we are generating pipelines for a CSV dataset. The 299_libras_move dataset is used for this example.

# %%
output_path = 'tmp/'
train_dataset = pd.read_csv('datasets/299_libras_move/train_data.csv')
test_dataset = pd.read_csv('datasets/299_libras_move/test_data.csv')

# %% [markdown]
# Removing the target column from the features for the train dataset

# %%
target_column = 'class'
X_train = train_dataset.drop(columns=[target_column])
X_train
# Out:
#      xcoord1  ycoord1  xcoord2  ycoord2  xcoord3  ycoord3  xcoord4  ycoord4  \
# 0    0.82979  0.76620  0.82979  0.76620  0.82979  0.77083  0.82785  0.77083
# 1    0.80271  0.54630  0.80077  0.54398  0.80271  0.54398  0.80271  0.54630
# 2    0.78917  0.59028  0.79110  0.59028  0.79110  0.59028  0.79304  0.59028
# 3    0.88395  0.61574  0.88201  0.61806  0.87234  0.62037  0.87041  0.61574
# 4    0.60155  0.77315  0.59768  0.77315  0.59961  0.77315  0.59381  0.77083
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 283  0.85300  0.57639  0.85493  0.57407  0.85300  0.57639  0.85300  0.57407
# 284  0.66925  0.78009  0.66925  0.78009  0.66925  0.78009  0.67118  0.78009
# 285  0.57060  0.65741  0.57060  0.65741  0.57060  0.65509  0.56867  0.65046
# 286  0.62282  0.65278  0.62476  0.65046  0.62669  0.64815  0.61315  0.63426
# 287  0.65571  0.51157  0.65571  0.51389  0.65571  0.51157  0.65571  0.51389
#
#      xcoord5  ycoord5  ...  xcoord41  ycoord41  xcoord42  ycoord42  xcoord43  \
# 0    0.82979  0.76620  ...   0.41199   0.45370   0.37524   0.43750   0.33269
# 1    0.80271  0.54398  ...   0.20503   0.64583   0.20503   0.68056   0.20696
# 2    0.79110  0.59028  ...   0.20503   0.57407   0.19149   0.57176   0.18569
# 3    0.84526  0.61574  ...   0.27079   0.65972   0.26886   0.62731   0.27660
# 4    0.58801  0.75000  ...   0.63830   0.47917   0.63250   0.52778   0.63830
# ..       ...      ...  ...       ...       ...       ...       ...       ...
# 283  0.85493  0.56944  ...   0.19923   0.80787   0.17021   0.79630   0.14313
# 284  0.66925  0.78009  ...   0.67311   0.28704   0.66925   0.26389   0.66731
# 285  0.54739  0.64120  ...   0.36944   0.62500   0.42166   0.62269   0.47389
# 286  0.55319  0.60185  ...   0.28433   0.66435   0.30754   0.63889   0.33462
# 287  0.65571  0.51157  ...   0.64603   0.46296   0.65377   0.48843   0.65571
#
#      ycoord43  xcoord44  ycoord44  xcoord45  ycoord45
# 0     0.43056   0.29787   0.44213   0.26886   0.47222
# 1     0.71296   0.21083   0.74537   0.21277   0.77315
# 2     0.57407   0.18956   0.57639   0.19149   0.56944
# 3     0.59259   0.27660   0.56250   0.27853   0.53009
# 4     0.57407   0.63830   0.63194   0.63830   0.68750
# ..        ...       ...       ...       ...       ...
# 283   0.75231   0.12959   0.69213   0.12959   0.62037
# 284   0.24306   0.66731   0.22454   0.66538   0.20602
# 285   0.62269   0.52418   0.63194   0.56286   0.64120
# 286   0.61574   0.37331   0.58102   0.42747   0.54398
# 287   0.49074   0.64990   0.46296   0.65377   0.45833
#
# [288 rows x 90 columns]

# %% [markdown]
# Selecting the target column for the train dataset

# %%
y_train = train_dataset[[target_column]]
y_train
# Out:
#      class
# 0       12
# 1       15
# 2        7
# 3       12
# 4        3
# ..     ...
# 283     12
# 284      8
# 285      2
# 286      1
# 287      9
#
# [288 rows x 1 columns]

# %% [markdown]
# ### Adding Your Primitives into AlphaAutoML's Search Space

# %%
automl = AutoMLClassifier(output_path, time_bound=1)

# %%
from alpha_automl.base_primitive import BasePrimitive

# Create a custom feature selection method
class MyDropFeatureSelector(BasePrimitive):
    # If running it in Windows or CUDA environment, this implementation should be in an external module.
    def __init__(self, variables):
        self.variables = variables
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X_dropped = X.drop(self.variables, axis = 1)
        return X_dropped

# Adding MyDropFeatureSelector to AlphaAutoML
object_dfs = MyDropFeatureSelector(['xcoord1', 'xcoord2'])
automl.add_primitives([(object_dfs, 'FEATURE_SELECTOR')])

# %% [markdown]
# ### Searching  Pipelines

# %%
automl.fit(X_train, y_train)
# Out:
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.125
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.027777777777777776
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.18055555555555555
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.19444444444444445
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.09722222222222222
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.5972222222222222
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.08333333333333333
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.06944444444444445
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.5416666666666666
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.2638888888888889
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.18055555555555555
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.16666666666666666
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.1388888888888889
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.027777777777777776
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.5416666666666666
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.4166666666666667
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.19444444444444445
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.19444444444444445
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.2361111111111111
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.19444444444444445
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.2361111111111111
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.6944444444444444
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.2916666666666667
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.125
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.6388888888888888
# INFO:alpha_automl.automl_api:Found 25 pipelines

# %% [markdown]
# After the pipeline search is complete, we can display the leaderboard:

# %%
automl.plot_leaderboard()
# Out:
# <style type="text/css">
# </style>
# <table id="T_db92a">
#   <thead>
#     <tr>
#       <th id="T_db92a_level0_col0" class="col_heading level0 col0" >ranking</th>
#       <th id="T_db92a_level0_col1" class="col_heading level0 col1" >pipeline</th>
#       <th id="T_db92a_level0_col2" class="col_heading level0 col2" >accuracy_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db92a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_db92a_row0_col1" class="data row0 col1" >MyDropFeatureSelector, KNeighborsClassifier</td>
#       <td id="T_db92a_row0_col2" class="data row0 col2" >0.694</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_db92a_row1_col1" class="data row1 col1" >MyDropFeatureSelector, LogisticRegression</td>
#       <td id="T_db92a_row1_col2" class="data row1 col2" >0.639</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_db92a_row2_col1" class="data row2 col1" >MyDropFeatureSelector, LinearDiscriminantAnalysis</td>
#       <td id="T_db92a_row2_col2" class="data row2 col2" >0.597</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_db92a_row3_col1" class="data row3 col1" >MaxAbsScaler, MultinomialNB</td>
#       <td id="T_db92a_row3_col2" class="data row3 col2" >0.542</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_db92a_row4_col1" class="data row4 col1" >MyDropFeatureSelector, MultinomialNB</td>
#       <td id="T_db92a_row4_col2" class="data row4 col2" >0.542</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_db92a_row5_col1" class="data row5 col1" >MaxAbsScaler, SelectKBest, KNeighborsClassifier</td>
#       <td id="T_db92a_row5_col2" class="data row5 col2" >0.417</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_db92a_row6_col1" class="data row6 col1" >MyDropFeatureSelector, QuadraticDiscriminantAnalysis</td>
#       <td id="T_db92a_row6_col2" class="data row6 col2" >0.292</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_db92a_row7_col1" class="data row7 col1" >MaxAbsScaler, GenericUnivariateSelect, ExtraTreesClassifier</td>
#       <td id="T_db92a_row7_col2" class="data row7 col2" >0.264</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_db92a_row8_col1" class="data row8 col1" >MaxAbsScaler, GenericUnivariateSelect, RandomForestClassifier</td>
#       <td id="T_db92a_row8_col2" class="data row8 col2" >0.236</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_db92a_row9_col1" class="data row9 col1" >MaxAbsScaler, GenericUnivariateSelect, BaggingClassifier</td>
#       <td id="T_db92a_row9_col2" class="data row9 col2" >0.236</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_db92a_row10_col1" class="data row10 col1" >MaxAbsScaler, GenericUnivariateSelect, QuadraticDiscriminantAnalysis</td>
#       <td id="T_db92a_row10_col2" class="data row10 col2" >0.194</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_db92a_row11_col1" class="data row11 col1" >MaxAbsScaler, GenericUnivariateSelect, SGDClassifier</td>
#       <td id="T_db92a_row11_col2" class="data row11 col2" >0.194</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_db92a_row12_col1" class="data row12 col1" >MaxAbsScaler, GenericUnivariateSelect, GradientBoostingClassifier</td>
#       <td id="T_db92a_row12_col2" class="data row12 col2" >0.194</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_db92a_row13_col1" class="data row13 col1" >MaxAbsScaler, GenericUnivariateSelect, GaussianNB</td>
#       <td id="T_db92a_row13_col2" class="data row13 col2" >0.194</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_db92a_row14_col1" class="data row14 col1" >MaxAbsScaler, GenericUnivariateSelect, KNeighborsClassifier</td>
#       <td id="T_db92a_row14_col2" class="data row14 col2" >0.181</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_db92a_row15_col1" class="data row15 col1" >MaxAbsScaler, GenericUnivariateSelect, SVC</td>
#       <td id="T_db92a_row15_col2" class="data row15 col2" >0.181</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_db92a_row16_col1" class="data row16 col1" >MaxAbsScaler, GenericUnivariateSelect, PassiveAggressiveClassifier</td>
#       <td id="T_db92a_row16_col2" class="data row16 col2" >0.167</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_db92a_row17_col1" class="data row17 col1" >MaxAbsScaler, GenericUnivariateSelect, LinearSVC</td>
#       <td id="T_db92a_row17_col2" class="data row17 col2" >0.139</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_db92a_row18_col1" class="data row18 col1" >MaxAbsScaler, GenericUnivariateSelect, LinearDiscriminantAnalysis</td>
#       <td id="T_db92a_row18_col2" class="data row18 col2" >0.125</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_db92a_row19_col1" class="data row19 col1" >GenericUnivariateSelect, LinearDiscriminantAnalysis</td>
#       <td id="T_db92a_row19_col2" class="data row19 col2" >0.125</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row20_col0" class="data row20 col0" >21</td>
#       <td id="T_db92a_row20_col1" class="data row20 col1" >MaxAbsScaler, GenericUnivariateSelect, LogisticRegression</td>
#       <td id="T_db92a_row20_col2" class="data row20 col2" >0.097</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row21_col0" class="data row21 col0" >22</td>
#       <td id="T_db92a_row21_col1" class="data row21 col1" >MaxAbsScaler, SelectKBest, MultinomialNB</td>
#       <td id="T_db92a_row21_col2" class="data row21 col2" >0.083</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row22_col0" class="data row22 col0" >23</td>
#       <td id="T_db92a_row22_col1" class="data row22 col1" >MaxAbsScaler, SelectPercentile, MultinomialNB</td>
#       <td id="T_db92a_row22_col2" class="data row22 col2" >0.069</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row23_col0" class="data row23 col0" >24</td>
#       <td id="T_db92a_row23_col1" class="data row23 col1" >MaxAbsScaler, GenericUnivariateSelect, MultinomialNB</td>
#       <td id="T_db92a_row23_col2" class="data row23 col2" >0.028</td>
#     </tr>
#     <tr>
#       <td id="T_db92a_row24_col0" class="data row24 col0" >25</td>
#       <td id="T_db92a_row24_col1" class="data row24 col1" >MaxAbsScaler, GenericUnivariateSelect, BernoulliNB</td>
#       <td id="T_db92a_row24_col2" class="data row24 col2" >0.028</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Exploring Pipelines

# %%
automl.plot_comparison_pipelines()
