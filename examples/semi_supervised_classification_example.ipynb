# %% [markdown]
# ## Solving Semi-Supervised Classification Tasks

# %% [markdown]
# First, import the class `AutoMLSemiSupervisedClassifier`

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from alpha_automl import AutoMLSemiSupervisedClassifier

# %% [markdown]
# ### Generating Pipelines for CSV Datasets
#
# In this example, we are generating pipelines for a CSV dataset.

# %%
output_path = 'tmp/'
dataset = pd.read_csv('datasets/semi/learningData.csv')
target_col = "defects"

X = dataset.drop(columns=[target_col])
y = dataset[[target_col]]

X_train, X_test, y_train, y_test = train_test_split(X, y)

X_test = X_test[~pd.isnull(y_test['defects'])]
y_test = y_test[~pd.isnull(y_test['defects'])]
y_test.value_counts()
# Out:
# defects
# False      466
# True       110
# dtype: int64

# %% [markdown]
# ### Searching Pipelines

# %%
automl = AutoMLSemiSupervisedClassifier(output_path, time_bound=10, verbose=False,
                                        split_strategy_kwargs={'test_size':.2})

automl.fit(X_train, y_train)
# Out:
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9136242208370436
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# INFO:gluonts.mx.context:Using CPU
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# INFO:gluonts.mx.context:Using CPU
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:14, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.778272484416741
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:15, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7800534283170079
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:25, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8076580587711487
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:51, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9082813891362422
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:14, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8806767586821014
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:15, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9091718610863758
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:16, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8263579697239537
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:22, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:24, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9839715048975958
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:25, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7880676758682101
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:26, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:58, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9982190560997328
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.918967052537845
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8076580587711487
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7880676758682101
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9973285841495992
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9848619768477294
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:39, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9946571682991986
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:39, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9715048975957257
# INFO:alpha_automl.automl_api:Found pipeline, time=0:02:41, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9982190560997328
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7105966162065895
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7649154051647373
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7898486197684773
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:03:50, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:04:30, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9821905609973286
# INFO:alpha_automl.automl_api:Found pipeline, time=0:04:46, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8308103294746215
# INFO:alpha_automl.automl_api:Found pipeline, time=0:04:48, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9091718610863758
# INFO:alpha_automl.automl_api:Found pipeline, time=0:04:48, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9893143365983972
# INFO:alpha_automl.automl_api:Found pipeline, time=0:04:51, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7800534283170079
# INFO:alpha_automl.automl_api:Found pipeline, time=0:04:52, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9955476402493322
# INFO:alpha_automl.automl_api:Found pipeline, time=0:04:59, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9910952804986642
# INFO:alpha_automl.automl_api:Found pipeline, time=0:05:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9857524487978628
# INFO:alpha_automl.automl_api:Found pipeline, time=0:06:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8103294746215494
# INFO:alpha_automl.automl_api:Found pipeline, time=0:06:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9919857524487978
# INFO:alpha_automl.automl_api:Found pipeline, time=0:06:13, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9910952804986642
# INFO:alpha_automl.automl_api:Found pipeline, time=0:06:19, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7978628673196796
# INFO:alpha_automl.automl_api:Found pipeline, time=0:06:27, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7880676758682101
# INFO:alpha_automl.automl_api:Found pipeline, time=0:06:30, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9617097061442564
# INFO:alpha_automl.automl_api:Found pipeline, time=0:08:25, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8886910062333038
# INFO:alpha_automl.automl_api:Found pipeline, time=0:08:53, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7809439002671417
# INFO:alpha_automl.automl_api:Found pipeline, time=0:08:56, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9964381121994658
# INFO:alpha_automl.automl_api:Found pipeline, time=0:09:49, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9510240427426536
# INFO:alpha_automl.automl_api:Found pipeline, time=0:09:49, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8130008904719501
# INFO:alpha_automl.automl_api:Found pipeline, time=0:09:49, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.7791629563668745
# INFO:alpha_automl.automl_api:Found pipeline, time=0:09:50, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:09:50, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9973285841495992
# INFO:alpha_automl.automl_api:Found pipeline, time=0:09:53, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.9928762243989314
# INFO:alpha_automl.automl_api:Found pipeline, time=0:09:55, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:09:56, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=0.8014247551202138
# INFO:alpha_automl.automl_api:Found 57 pipelines

# %% [markdown]
# ### Exploring Pipelines
#
# After the pipeline search is complete, we can display the leaderboard:

# %%
automl.plot_leaderboard()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c1fbc">
#   <thead>
#     <tr>
#       <th id="T_c1fbc_level0_col0" class="col_heading level0 col0" >ranking</th>
#       <th id="T_c1fbc_level0_col1" class="col_heading level0 col1" >pipeline</th>
#       <th id="T_c1fbc_level0_col2" class="col_heading level0 col2" >f1_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c1fbc_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c1fbc_row0_col1" class="data row0 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, RandomForestClassifier</td>
#       <td id="T_c1fbc_row0_col2" class="data row0 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c1fbc_row1_col1" class="data row1 col1" >SimpleImputer, MaxAbsScaler, AutonBox, RandomForestClassifier</td>
#       <td id="T_c1fbc_row1_col2" class="data row1 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c1fbc_row2_col1" class="data row2 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, XGBClassifier</td>
#       <td id="T_c1fbc_row2_col2" class="data row2 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c1fbc_row3_col1" class="data row3 col1" >SimpleImputer, AutonBox, RandomForestClassifier</td>
#       <td id="T_c1fbc_row3_col2" class="data row3 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c1fbc_row4_col1" class="data row4 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, GradientBoostingClassifier</td>
#       <td id="T_c1fbc_row4_col2" class="data row4 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_c1fbc_row5_col1" class="data row5 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, DecisionTreeClassifier</td>
#       <td id="T_c1fbc_row5_col2" class="data row5 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_c1fbc_row6_col1" class="data row6 col1" >SimpleImputer, RobustScaler, SelfTrainingClassifier, RandomForestClassifier</td>
#       <td id="T_c1fbc_row6_col2" class="data row6 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_c1fbc_row7_col1" class="data row7 col1" >SimpleImputer, StandardScaler, SelfTrainingClassifier, RandomForestClassifier</td>
#       <td id="T_c1fbc_row7_col2" class="data row7 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_c1fbc_row8_col1" class="data row8 col1" >SimpleImputer, RobustScaler, AutonBox, RandomForestClassifier</td>
#       <td id="T_c1fbc_row8_col2" class="data row8 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_c1fbc_row9_col1" class="data row9 col1" >SimpleImputer, StandardScaler, AutonBox, RandomForestClassifier</td>
#       <td id="T_c1fbc_row9_col2" class="data row9 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_c1fbc_row10_col1" class="data row10 col1" >SimpleImputer, SelfTrainingClassifier, BaggingClassifier</td>
#       <td id="T_c1fbc_row10_col2" class="data row10 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_c1fbc_row11_col1" class="data row11 col1" >SimpleImputer, SelfTrainingClassifier, XGBClassifier</td>
#       <td id="T_c1fbc_row11_col2" class="data row11 col2" >1.000</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_c1fbc_row12_col1" class="data row12 col1" >SimpleImputer, SelfTrainingClassifier, RandomForestClassifier</td>
#       <td id="T_c1fbc_row12_col2" class="data row12 col2" >0.998</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_c1fbc_row13_col1" class="data row13 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, LGBMClassifier</td>
#       <td id="T_c1fbc_row13_col2" class="data row13 col2" >0.998</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_c1fbc_row14_col1" class="data row14 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, BaggingClassifier</td>
#       <td id="T_c1fbc_row14_col2" class="data row14 col2" >0.997</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_c1fbc_row15_col1" class="data row15 col1" >SimpleImputer, MaxAbsScaler, AutonBox, PassiveAggressiveClassifier</td>
#       <td id="T_c1fbc_row15_col2" class="data row15 col2" >0.997</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_c1fbc_row16_col1" class="data row16 col1" >SimpleImputer, MaxAbsScaler, AutonBox, GradientBoostingClassifier</td>
#       <td id="T_c1fbc_row16_col2" class="data row16 col2" >0.996</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_c1fbc_row17_col1" class="data row17 col1" >SimpleImputer, MaxAbsScaler, AutonBox, BaggingClassifier</td>
#       <td id="T_c1fbc_row17_col2" class="data row17 col2" >0.996</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_c1fbc_row18_col1" class="data row18 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, SGDClassifier</td>
#       <td id="T_c1fbc_row18_col2" class="data row18 col2" >0.995</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_c1fbc_row19_col1" class="data row19 col1" >SimpleImputer, MaxAbsScaler, AutonBox, DecisionTreeClassifier</td>
#       <td id="T_c1fbc_row19_col2" class="data row19 col2" >0.993</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row20_col0" class="data row20 col0" >21</td>
#       <td id="T_c1fbc_row20_col1" class="data row20 col1" >SimpleImputer, MaxAbsScaler, AutonBox, SGDClassifier</td>
#       <td id="T_c1fbc_row20_col2" class="data row20 col2" >0.992</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row21_col0" class="data row21 col0" >22</td>
#       <td id="T_c1fbc_row21_col1" class="data row21 col1" >SimpleImputer, MaxAbsScaler, AutonBox, SVC</td>
#       <td id="T_c1fbc_row21_col2" class="data row21 col2" >0.991</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row22_col0" class="data row22 col0" >23</td>
#       <td id="T_c1fbc_row22_col1" class="data row22 col1" >SimpleImputer, MaxAbsScaler, AutonBox, LogisticRegression</td>
#       <td id="T_c1fbc_row22_col2" class="data row22 col2" >0.991</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row23_col0" class="data row23 col0" >24</td>
#       <td id="T_c1fbc_row23_col1" class="data row23 col1" >SimpleImputer, MaxAbsScaler, AutonBox, LinearSVC</td>
#       <td id="T_c1fbc_row23_col2" class="data row23 col2" >0.989</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row24_col0" class="data row24 col0" >25</td>
#       <td id="T_c1fbc_row24_col1" class="data row24 col1" >SimpleImputer, MaxAbsScaler, AutonBox, XGBClassifier</td>
#       <td id="T_c1fbc_row24_col2" class="data row24 col2" >0.986</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row25_col0" class="data row25 col0" >26</td>
#       <td id="T_c1fbc_row25_col1" class="data row25 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, LogisticRegression</td>
#       <td id="T_c1fbc_row25_col2" class="data row25 col2" >0.985</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row26_col0" class="data row26 col0" >27</td>
#       <td id="T_c1fbc_row26_col1" class="data row26 col1" >SimpleImputer, MaxAbsScaler, SelfTrainingClassifier, KNeighborsClassifier</td>
#       <td id="T_c1fbc_row26_col2" class="data row26 col2" >0.984</td>
#     </tr>
#     <tr>
#       <td id="T_c1fbc_row27_col0" class="data row2

# %% [markdown]
# In order to explore the produced pipelines, we can use [PipelineProfiler](https://github.com/VIDA-NYU/PipelineVis). PipelineProfiler is a visualization that enables users to compare and explore the pipelines generated by the AlphaAutoML system.
#
# After the pipeline search process is completed, we can use PipelineProfiler with:

# %%
automl.plot_comparison_pipelines()

# %% [markdown]
# ### Testing Pipelines
#
# Pipeline predictions are accessed with:

# %%
y_pred = automl.predict(X_test)
y_pred
# Out:
# array([[False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [True],
#        [False],
#        [True],
#        [True],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [True],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [True],
#        [True],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [True],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]], dtype=object)

# %%
automl.score(X_test, y_test)
# Out:
# INFO:alpha_automl.automl_api:Metric: f1_score, Score: 1.0
# {'metric': 'f1_score', 'score': 1.0}
