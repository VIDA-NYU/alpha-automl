# %% [markdown]
# ## Solving Tabular Regression Tasks

# %% [markdown]
# First, import the class `AutoMLRegressor`

# %%
from alpha_automl  import AutoMLRegressor
import pandas as pd

# %% [markdown]
# ### Generating Pipelines for CSV Datasets

# %% [markdown]
# In this example, we are generating pipelines for a CSV dataset. The 196_autoMpg dataset is used for this example.

# %%
output_path = 'tmp/'
train_dataset = pd.read_csv('datasets/196_autoMpg/train_data.csv')
test_dataset = pd.read_csv('datasets/196_autoMpg/test_data.csv')

# %% [markdown]
# Removing the target column from the features for the train dataset

# %%
target_column = 'class'
X_train = train_dataset.drop(columns=[target_column])
X_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model  origin
# 0            8         350.0       165.0    3693          11.5     70       1
# 1            8         318.0       150.0    3436          11.0     70       1
# 2            8         302.0       140.0    3449          10.5     70       1
# 3            8         454.0       220.0    4354           9.0     70       1
# 4            8         440.0       215.0    4312           8.5     70       1
# ..         ...           ...         ...     ...           ...    ...     ...
# 293          4         144.0        96.0    2665          13.9     82       3
# 294          4         135.0        84.0    2370          13.0     82       1
# 295          4         151.0        90.0    2950          17.3     82       1
# 296          4         135.0        84.0    2295          11.6     82       1
# 297          4         119.0        82.0    2720          19.4     82       1
#
# [298 rows x 7 columns]

# %% [markdown]
# Selecting the target column for the train dataset

# %%
y_train = train_dataset[[target_column]]
y_train
# Out:
#      class
# 0     15.0
# 1     18.0
# 2     17.0
# 3     14.0
# 4     14.0
# ..     ...
# 293   32.0
# 294   36.0
# 295   27.0
# 296   32.0
# 297   31.0
#
# [298 rows x 1 columns]

# %% [markdown]
# ### Searching  Pipelines

# %%
automl = AutoMLRegressor(output_path, time_bound=10)
automl.fit(X_train, y_train)
# Out:
# INFO:datamart_profiler.core:Setting column names from header
# INFO:datamart_profiler.core:Identifying types, 7 columns...
# INFO:datamart_profiler.core:Processing column 0 'cylinders'...
# INFO:datamart_profiler.core:Column type http://schema.org/Integer []
# INFO:datamart_profiler.core:Processing column 1 'displacement'...
# INFO:datamart_profiler.core:Column type http://schema.org/Integer []
# INFO:datamart_profiler.core:Processing column 2 'horsepower'...
# INFO:datamart_profiler.core:Column type http://schema.org/Integer []
# INFO:datamart_profiler.core:Processing column 3 'weight'...
# INFO:datamart_profiler.core:Column type http://schema.org/Integer []
# INFO:datamart_profiler.core:Processing column 4 'acceleration'...
# INFO:datamart_profiler.core:Column type http://schema.org/Float []
# INFO:datamart_profiler.core:Processing column 5 'model'...
# INFO:datamart_profiler.core:Column type http://schema.org/Integer []
# INFO:datamart_profiler.core:Processing column 6 'origin'...
# INFO:datamart_profiler.core:Column type http://schema.org/Integer []
# INFO:alpha_automl.data_profiler:Results of profiling data: non-numeric features = dict_keys([]), useless columns = [], missing values = True
# INFO:alpha_automl.pipeline_synthesis.setup_search:Creating a manual grammar
# INFO:alpha_automl.primitive_loader:Hierarchy of all primitives loaded
# INFO:alpha_automl.grammar_loader:Creating task grammar for task REGRESSION_TASK
# INFO:alpha_automl.grammar_loader:Task grammar: Grammar with 33 productions (start state = S)
#     S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
#     ENCODERS -> 'E'
#     IMPUTATION -> 'sklearn.impute.SimpleImputer'
#     FEATURE_SCALING -> 'sklearn.preprocessing.MaxAbsScaler'
#     FEATURE_SCALING -> 'sklearn.preprocessing.RobustScaler'
#     FEATURE_SCALING -> 'sklearn.preprocessing.StandardScaler'
#     FEATURE_SCALING -> 'E'
#     FEATURE_SELECTION -> 'sklearn.feature_selection.GenericUnivariateSelect'
#     FEATURE_SELECTION -> 'sklearn.feature_selection.SelectPercentile'
#     FEATURE_SELECTION -> 'sklearn.feature_selection.SelectKBest'
#     FEATURE_SELECTION -> 'E'
#     REGRESSION -> 'sklearn.linear_model.ARDRegression'
#     REGRESSION -> 'sklearn.tree.DecisionTreeRegressor'
#     REGRESSION -> 'sklearn.ensemble.ExtraTreesRegressor'
#     REGRESSION -> 'sklearn.gaussian_process.GaussianProcessRegressor'
#     REGRESSION -> 'sklearn.ensemble.GradientBoostingRegressor'
#     REGRESSION -> 'sklearn.neighbors.KNeighborsRegressor'
#     REGRESSION -> 'sklearn.linear_model.Lars'
#     REGRESSION -> 'sklearn.linear_model.Lasso'
#     REGRESSION -> 'sklearn.linear_model.LassoCV'
#     REGRESSION -> 'sklearn.svm.LinearSVR'
#     REGRESSION -> 'sklearn.linear_model.PassiveAggressiveRegressor'
#     REGRESSION -> 'sklearn.ensemble.RandomForestRegressor'
#     REGRESSION -> 'sklearn.linear_model.Ridge'
#     REGRESSION -> 'sklearn.linear_model.SGDRegressor'
#     REGRESSION -> 'sklearn.svm.SVR'
#     REGRESSION -> 'sklearn.linear_model.BayesianRidge'
#     REGRESSION -> 'sklearn.linear_model.ElasticNet'
#     REGRESSION -> 'sklearn.linear_model.HuberRegressor'
#     REGRESSION -> 'sklearn.linear_model.LinearRegression'
#     REGRESSION -> 'sklearn.linear_model.RANSACRegressor'
#     REGRESSION -> 'sklearn.linear_model.RidgeCV'
#     REGRESSION -> 'sklearn.linear_model.TheilSenRegressor'
# INFO:alpha_automl.grammar_loader:Creating game grammar
# INFO:alpha_automl.pipeline_search.Coach:------ITER 1------
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011586031
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010356691
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.0112097915
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010311055
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010343928
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 0
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.LinearRegression
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.LinearRegression
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010728438
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Lars
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.Lars
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010462175
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.0106828045
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.ensemble.RandomForestRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.ensemble.RandomForestRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010854425
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Ridge
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.Ridge
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011047
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 25
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011537404
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010682669
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectKBest
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011077367
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011015028
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectPercentile
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectPercentile|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010376017
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 9
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectKBest
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011919077
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011404247
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.StandardScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.StandardScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010306013
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.0119544715
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010584405
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.01223522
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.01228736
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_synthesis.pipeline_builder:New pipelined created:
# Pipeline(steps=[('sklearn.impute.SimpleImputer',
#                  SimpleImputer(strategy='most_frequent')),
#                 ('sklearn.preprocessing.RobustScaler', RobustScaler()),
#                 ('sklearn.feature_selection.SelectKBest', SelectKBest()),
#                 ('sklearn.svm.SVR', SVR())])
# WARNING:alpha_automl.scorer:Exception scoring a pipeline
# WARNING:alpha_automl.scorer:Detailed error:
# Traceback (most recent call last):
#   File "/Users/rlopez/D3M/alpha-automl/alpha_automl/scorer.py", line 73, in score_pipeline
#     scores = cross_val_score(pipeline, X, y, cv=splitting_strategy, scoring=scoring, error_score='raise')
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 515, in cross_val_score
#     cv_results = cross_validate(
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 266, in cross_validate
#     results = parallel(
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/pipeline.py", line 401, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/pipeline.py", line 359, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/utils/_set_output.py", line 142, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/base.py", line 862, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py", line 471, in fit
#     self._check_params(X, y)
#   File "/Users/rlopez/opt/anaconda3/envs/alphaautoml/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py", line 672, in _check_params
#     raise ValueError(
# ValueError: k should be <= n_features = 7; got 10. Use k='all' to return all features.
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|sklearn.feature_selection.SelectKBest|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011586031
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010356691
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.0112097915
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010311055
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010343928
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 0
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.LinearRegression
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.LinearRegression
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010728438
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Lars
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.Lars
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010462175
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.0106828045
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.ensemble.RandomForestRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.ensemble.RandomForestRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010854425
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Ridge
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.Ridge
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011047
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 31
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011179901
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010282252
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectKBest
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectKBest|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010687122
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.01061971
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectPercentile
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectPercentile|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.009979498
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 10
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> E
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011132346
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.01057513
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.StandardScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.009486025
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.01122217
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.009773977
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.012085124
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.RobustScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011523909
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.StandardScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010393776
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010702939
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|FEATURE_SCALING|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.MaxAbsScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.MaxAbsScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010803962
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.StandardScaler
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_synthesis.pipeline_builder:New pipelined created:
# Pipeline(steps=[('sklearn.impute.SimpleImputer',
#                  SimpleImputer(strategy='most_frequent')),
#                 ('sklearn.preprocessing.StandardScaler', StandardScaler()),
#                 ('sklearn.linear_model.RidgeCV', RidgeCV())])
# INFO:alpha_automl.scorer:Score: -11.084285028384294
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:findwin -1
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:findwin -1
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:findwin -1
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|ENCODERS|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.StandardScaler|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:findwin -1
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 1
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:findwin 1
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.084285028384294
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011586031
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010356691
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.0112097915
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.RidgeCV
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010311055
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: S
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> E
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010343928
# INFO:alpha_automl.pipeline_search.Coach:COACH ACTION 0
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: S -> IMPUTATION ENCODERS FEATURE_SCALING FEATURE_SELECTION REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.LinearRegression
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.LinearRegression
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010728438
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Lars
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.Lars
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010462175
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.svm.SVR
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.0106828045
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.ensemble.RandomForestRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.ensemble.RandomForestRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010854425
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Ridge
# ...
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011644993
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|sklearn.preprocessing.RobustScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010721036
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectPercentile
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|ENCODERS|FEATURE_SCALING|sklearn.feature_selection.SelectPercentile|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010014566
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: ENCODERS -> E
# INFO:alpha_automl.pipeline_search.Arena:Turn 3
# INFO:alpha_automl.pipeline_search.Arena:Player 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.TheilSenRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.TheilSenRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011032635
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|sklearn.preprocessing.RobustScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011565
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.012485776
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectPercentile
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|sklearn.feature_selection.SelectPercentile|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.010885107
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.ensemble.GradientBoostingRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: IMPUTATION|FEATURE_SCALING|FEATURE_SELECTION|sklearn.ensemble.GradientBoostingRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.012191102
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: IMPUTATION -> sklearn.impute.SimpleImputer
# INFO:alpha_automl.pipeline_search.Arena:Turn 4
# INFO:alpha_automl.pipeline_search.Arena:Player -1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.tree.DecisionTreeRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|sklearn.tree.DecisionTreeRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.012104797
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.TheilSenRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.TheilSenRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.012002439
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.RobustScaler
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.RobustScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.0125232395
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.013394407
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectPercentile
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|FEATURE_SCALING|sklearn.feature_selection.SelectPercentile|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.01184253
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SCALING -> sklearn.preprocessing.MaxAbsScaler
# INFO:alpha_automl.pipeline_search.Arena:Turn 5
# INFO:alpha_automl.pipeline_search.Arena:Player 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.tree.DecisionTreeRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|sklearn.tree.DecisionTreeRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011792314
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.TheilSenRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|sklearn.linear_model.TheilSenRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011689567
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.013096228
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.SelectPercentile
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.SelectPercentile|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.011533547
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 5
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.ensemble.GradientBoostingRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|FEATURE_SELECTION|sklearn.ensemble.GradientBoostingRegressor
# INFO:alpha_automl.pipeline_search.MCTS:Prediction 0.012841433
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: FEATURE_SELECTION -> sklearn.feature_selection.GenericUnivariateSelect
# INFO:alpha_automl.pipeline_search.Arena:Turn 6
# INFO:alpha_automl.pipeline_search.Arena:Player -1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|REGRESSION
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 1
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|sklearn.linear_model.Lasso
# INFO:alpha_automl.pipeline_synthesis.pipeline_builder:New pipelined created:
# Pipeline(steps=[('sklearn.impute.SimpleImputer',
#                  SimpleImputer(strategy='most_frequent')),
#                 ('sklearn.preprocessing.MaxAbsScaler', MaxAbsScaler()),
#                 ('sklearn.feature_selection.GenericUnivariateSelect',
#                  GenericUnivariateSelect()),
#                 ('sklearn.linear_model.Lasso', Lasso())])
# INFO:alpha_automl.scorer:Score: -17.80821710539882
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:findwin -1
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 2
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.ensemble.GradientBoostingRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|sklearn.ensemble.GradientBoostingRegressor
# INFO:alpha_automl.pipeline_synthesis.pipeline_builder:New pipelined created:
# Pipeline(steps=[('sklearn.impute.SimpleImputer',
#                  SimpleImputer(strategy='most_frequent')),
#                 ('sklearn.preprocessing.MaxAbsScaler', MaxAbsScaler()),
#                 ('sklearn.feature_selection.GenericUnivariateSelect',
#                  GenericUnivariateSelect()),
#                 ('sklearn.ensemble.GradientBoostingRegressor',
#                  GradientBoostingRegressor())])
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.80821710539882
# INFO:alpha_automl.scorer:Score: -19.973513956840808
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:findwin -1
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 3
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.LassoCV
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|sklearn.linear_model.LassoCV
# INFO:alpha_automl.pipeline_synthesis.pipeline_builder:New pipelined created:
# Pipeline(steps=[('sklearn.impute.SimpleImputer',
#                  SimpleImputer(strategy='most_frequent')),
#                 ('sklearn.preprocessing.MaxAbsScaler', MaxAbsScaler()),
#                 ('sklearn.feature_selection.GenericUnivariateSelect',
#                  GenericUnivariateSelect()),
#                 ('sklearn.linear_model.LassoCV', LassoCV())])
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.973513956840808
# INFO:alpha_automl.scorer:Score: -18.902129567958312
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:findwin -1
# INFO:alpha_automl.pipeline_search.MCTS:MCTS SIMULATION 4
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|REGRESSION
# INFO:alpha_automl.pipeline_search.pipeline.PipelineLogic:MOVE ACTION: REGRESSION -> sklearn.linear_model.SGDRegressor
# INFO:alpha_automl.pipeline_search.pipeline.PipelineGame:PIPELINE: sklearn.impute.SimpleImputer|sklearn.preprocessing.MaxAbsScaler|sklearn.feature_selection.GenericUnivariateSelect|sklearn.linear_model.SGDRegressor
# INFO:alpha_automl.pipeline_synthesis.pipeline_builder:New pipelined created:
# Pipeline(steps=[('sklearn.impute.SimpleImputer',
#                  SimpleImputer(strategy='most_frequent')),
#                 ('sklearn.preprocessing.MaxAbsScaler', MaxAbsScaler()),
#                 ('sklearn.feature_selection.GenericUnivariateSelect',
#                  GenericUnivariateSelect()),
#                 ('sklearn.linear_model.SGDRegressor', SGDRegressor())])
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.902129567958312
# INFO:alpha_automl.automl_api:Found 22 pipelines

# %% [markdown]
# After the pipeline search is complete, we can display the leaderboard:

# %%
automl.plot_leaderboard()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9efab">
#   <thead>
#     <tr>
#       <th id="T_9efab_level0_col0" class="col_heading level0 col0" >ranking</th>
#       <th id="T_9efab_level0_col1" class="col_heading level0 col1" >pipeline</th>
#       <th id="T_9efab_level0_col2" class="col_heading level0 col2" >max_error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9efab_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9efab_row0_col1" class="data row0 col1" >SimpleImputer, StandardScaler, LinearRegression</td>
#       <td id="T_9efab_row0_col2" class="data row0 col2" >-10.982554</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_9efab_row1_col1" class="data row1 col1" >SimpleImputer, StandardScaler, RidgeCV</td>
#       <td id="T_9efab_row1_col2" class="data row1 col2" >-11.084285</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_9efab_row2_col1" class="data row2 col1" >SimpleImputer, MaxAbsScaler, RidgeCV</td>
#       <td id="T_9efab_row2_col2" class="data row2 col2" >-11.617772</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_9efab_row3_col1" class="data row3 col1" >SimpleImputer, RobustScaler, SVR</td>
#       <td id="T_9efab_row3_col2" class="data row3 col2" >-14.347167</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_9efab_row4_col1" class="data row4 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, Lasso</td>
#       <td id="T_9efab_row4_col2" class="data row4 col2" >-17.808217</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_9efab_row5_col1" class="data row5 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, ExtraTreesRegressor</td>
#       <td id="T_9efab_row5_col2" class="data row5 col2" >-18.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_9efab_row6_col1" class="data row6 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, DecisionTreeRegressor</td>
#       <td id="T_9efab_row6_col2" class="data row6 col2" >-18.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_9efab_row7_col1" class="data row7 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, Ridge</td>
#       <td id="T_9efab_row7_col2" class="data row7 col2" >-18.591397</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_9efab_row8_col1" class="data row8 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, LassoCV</td>
#       <td id="T_9efab_row8_col2" class="data row8 col2" >-18.902130</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_9efab_row9_col1" class="data row9 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, RidgeCV</td>
#       <td id="T_9efab_row9_col2" class="data row9 col2" >-18.924943</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_9efab_row10_col1" class="data row10 col1" >SimpleImputer, MaxAbsScaler, SelectPercentile, RidgeCV</td>
#       <td id="T_9efab_row10_col2" class="data row10 col2" >-18.924943</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_9efab_row11_col1" class="data row11 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, ARDRegression</td>
#       <td id="T_9efab_row11_col2" class="data row11 col2" >-18.954186</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_9efab_row12_col1" class="data row12 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, Lars</td>
#       <td id="T_9efab_row12_col2" class="data row12 col2" >-18.965394</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_9efab_row13_col1" class="data row13 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, LinearRegression</td>
#       <td id="T_9efab_row13_col2" class="data row13 col2" >-18.965394</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_9efab_row14_col1" class="data row14 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, HuberRegressor</td>
#       <td id="T_9efab_row14_col2" class="data row14 col2" >-19.211954</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_9efab_row15_col1" class="data row15 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, ElasticNet</td>
#       <td id="T_9efab_row15_col2" class="data row15 col2" >-19.240392</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_9efab_row16_col1" class="data row16 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, RandomForestRegressor</td>
#       <td id="T_9efab_row16_col2" class="data row16 col2" >-19.260790</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_9efab_row17_col1" class="data row17 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, TheilSenRegressor</td>
#       <td id="T_9efab_row17_col2" class="data row17 col2" >-19.668361</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_9efab_row18_col1" class="data row18 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, GradientBoostingRegressor</td>
#       <td id="T_9efab_row18_col2" class="data row18 col2" >-19.973514</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_9efab_row19_col1" class="data row19 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, SVR</td>
#       <td id="T_9efab_row19_col2" class="data row19 col2" >-20.432852</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row20_col0" class="data row20 col0" >21</td>
#       <td id="T_9efab_row20_col1" class="data row20 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, KNeighborsRegressor</td>
#       <td id="T_9efab_row20_col2" class="data row20 col2" >-21.100000</td>
#     </tr>
#     <tr>
#       <td id="T_9efab_row21_col0" class="data row21 col0" >22</td>
#       <td id="T_9efab_row21_col1" class="data row21 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, PassiveAggressiveRegressor</td>
#       <td id="T_9efab_row21_col2" class="data row21 col2" >-22.545468</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Removing the target column from the features for the test dataset

# %%
X_test = test_dataset.drop(columns=[target_column])
X_test
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  model  origin
# 0           8           307       130.0    3504          12.0     70       1
# 1           8           304       150.0    3433          12.0     70       1
# 2           8           429       198.0    4341          10.0     70       1
# 3           8           390       190.0    3850           8.5     70       1
# 4           6           198        95.0    2833          15.5     70       1
# ..        ...           ...         ...     ...           ...    ...     ...
# 95          6           181       110.0    2945          16.4     82       1
# 96          6           232       112.0    2835          14.7     82       1
# 97          4           140        86.0    2790          15.6     82       1
# 98          4            97        52.0    2130          24.6     82       2
# 99          4           120        79.0    2625          18.6     82       1
#
# [100 rows x 7 columns]

# %% [markdown]
# Selecting the target column for the test dataset

# %%
y_test = test_dataset[[target_column]]
y_test
# Out:
#     class
# 0    18.0
# 1    16.0
# 2    15.0
# 3    15.0
# 4    22.0
# ..    ...
# 95   25.0
# 96   22.0
# 97   27.0
# 98   44.0
# 99   28.0
#
# [100 rows x 1 columns]

# %% [markdown]
# Pipeline predictions are accessed with:

# %%
y_pred = automl.predict(X_test)
y_pred
# Out:
# array([[14.88126855],
#        [15.11125796],
#        [ 9.87748377],
#        [12.63954372],
#        [18.92734178],
#        [25.54918914],
#        [22.72537224],
#        [ 7.47411631],
#        [23.07557363],
#        [25.7592489 ],
#        [21.14299456],
#        [ 9.89495727],
#        [ 6.45203815],
#        [19.2127908 ],
#        [22.57707044],
#        [27.44120371],
#        [25.14682615],
#        [26.33190746],
#        [11.23649046],
#        [10.88025371],
#        [13.72269498],
#        [12.72190265],
#        [12.77477908],
#        [20.43845785],
#        [23.82274486],
#        [20.75269993],
#        [24.8211903 ],
#        [27.46991951],
#        [ 8.35733714],
#        [12.55358309],
#        [ 9.68480114],
#        [20.86344088],
#        [ 8.73571356],
#        [27.27370345],
#        [22.9574655 ],
#        [25.64477326],
#        [11.98137611],
#        [26.68863942],
#        [16.07830408],
#        [21.98728636],
#        [23.88439743],
#        [13.13527892],
#        [26.87858751],
#        [26.78901014],
#        [20.3738318 ],
#        [12.42236264],
#        [23.95697144],
#        [27.67579111],
#        [29.36942563],
#        [24.50914644],
#        [24.40968352],
#        [32.1913938 ],
#        [28.01400519],
#        [32.97161226],
#        [16.76160055],
#        [25.33798772],
#        [32.02387532],
#        [16.98098852],
#        [20.42106758],
#        [16.13607451],
#        [15.4305131 ],
#        [24.86449957],
#        [28.68858813],
#        [33.32483805],
#        [34.36891867],
#        [22.05188181],
#        [21.81554154],
#        [21.61576657],
#        [25.04993107],
#        [23.85173303],
#        [23.46607711],
#        [20.0056665 ],
#        [19.55917003],
#        [33.81876838],
#        [20.29465754],
#        [26.22243193],
#        [34.4082766 ],
#        [30.07738376],
#        [26.59752928],
#        [31.07545335],
#        [32.83505054],
#        [27.66247989],
#        [31.12634905],
#        [32.23977884],
#        [30.3850732 ],
#        [29.53684333],
#        [29.50966091],
#        [30.07790702],
#        [27.85726733],
#        [34.81909735],
#        [36.10187953],
#        [36.41673932],
#        [32.48758225],
#        [35.05130958],
#        [36.26556211],
#        [27.38077962],
#        [28.49874579],
#        [28.34862261],
#        [34.66890151],
#        [29.50804119]])

# %% [markdown]
# The pipeline can be evaluated against a held out dataset with the function call:

# %%
automl.score(X_test, y_test)
# Out:
# INFO:alpha_automl.automl_api:Metric: max_error, Score: 9.331098492370522
# {'metric': 'max_error', 'score': 9.331098492370522}

# %% [markdown]
# ### Visualizing pipelines using Pipeline Profiler

# %% [markdown]
# In order to explore the produced pipelines, we can use [PipelineProfiler](https://github.com/VIDA-NYU/PipelineVis). PipelineProfiler is a visualization that enables users to compare and explore the pipelines generated by the AlphaAutoML system.
#
# After the pipeline search process is completed, we can use PipelineProfiler with:

# %%
automl.plot_comparison_pipelines()

# %% [markdown]
# For more information about how to use PipelineProfiler, click [here](https://towardsdatascience.com/exploring-auto-sklearn-models-with-pipelineprofiler-5b2c54136044). There is also a video demo available [here](https://www.youtube.com/watch?v=2WSYoaxLLJ8).
