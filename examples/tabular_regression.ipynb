# %% [markdown]
# ## Solving Tabular Regression Tasks

# %% [markdown]
# First, import the class `AutoMLRegressor`

# %%
from alpha_automl  import AutoMLRegressor
import pandas as pd

# %% [markdown]
# ### Generating Pipelines for CSV Datasets

# %% [markdown]
# In this example, we are generating pipelines for a CSV dataset. The 196_autoMpg dataset is used for this example.

# %%
output_path = 'tmp/'
train_dataset = pd.read_csv('datasets/196_autoMpg/train_data.csv')
test_dataset = pd.read_csv('datasets/196_autoMpg/test_data.csv')

# %% [markdown]
# Removing the target column from the features for the train dataset

# %%
target_column = 'class'
X_train = train_dataset.drop(columns=[target_column])
X_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model  origin
# 0            8         350.0       165.0    3693          11.5     70       1
# 1            8         318.0       150.0    3436          11.0     70       1
# 2            8         302.0       140.0    3449          10.5     70       1
# 3            8         454.0       220.0    4354           9.0     70       1
# 4            8         440.0       215.0    4312           8.5     70       1
# ..         ...           ...         ...     ...           ...    ...     ...
# 293          4         144.0        96.0    2665          13.9     82       3
# 294          4         135.0        84.0    2370          13.0     82       1
# 295          4         151.0        90.0    2950          17.3     82       1
# 296          4         135.0        84.0    2295          11.6     82       1
# 297          4         119.0        82.0    2720          19.4     82       1
#
# [298 rows x 7 columns]

# %% [markdown]
# Selecting the target column for the train dataset

# %%
y_train = train_dataset[[target_column]]
y_train
# Out:
#      class
# 0     15.0
# 1     18.0
# 2     17.0
# 3     14.0
# 4     14.0
# ..     ...
# 293   32.0
# 294   36.0
# 295   27.0
# 296   32.0
# 297   31.0
#
# [298 rows x 1 columns]

# %% [markdown]
# ### Searching  Pipelines

# %%
automl = AutoMLRegressor(output_path, time_bound=10)
automl.fit(X_train, y_train)
# Out:
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.084285028384294
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.92494330404196
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.617772389342438
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.92494330404196
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.982554036634546
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.347166795046391
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.95418649071102
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.965393586386423
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.96539358638642
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-20.432852435034484
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.26079006410256
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.59139709362848
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-22.545468428033516
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.211953658852856
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-21.1
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.24039199159428
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.668361146810472
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.80821710539882
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.973513956840808
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.902129567958312
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.710754741259937
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.99093105093636
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-20.326457977294922
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.954186490711017
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.83481586711389
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.590132459061568
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.982554036634532
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.75006413248844
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.965393586386423
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.57882823505859
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-16.717000000000002
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-15.082542479837358
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.361000000000004
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.707122412570925
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-12.496934720303596
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.982554036634546
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.48
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.646970512114574
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-12.588707496188448
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-20.5
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.80821710539882
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-15.893503888673639
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.486757143086582
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.919426879284877
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.09415096463992
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-90.48655517101288
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.587804833524139
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.96539358638643
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.95418649072443
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.960630922947452
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.965393586386426
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-20.43285243503448
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.088161044796784
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-12.823431131251276
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.22732771978269
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-16.747000000000003
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.15292857142857
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.41747619047619
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.91822000563559
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.55926149284314
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.21206058472361
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-21.1
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.07464736945662
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.97370622280833
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.0
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.873754378560676
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.973513956840808
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.902129567958315
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.94330755341251
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.712788733291774
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-20.530643463134766
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.506
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.227327719778302
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.59139709362848
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.95418649071102
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.363685876993259
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-15.393005101742997
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.92
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-12.493780988598637
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.192084826382263
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.95418649072443
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.751060051881502
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-13.386756576635378
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.945468803198843
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.586822788872635
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-13.907023294689136
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.00334989878315
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.535857289279676
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-16.200859471223946
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.965391614633024
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.084285028389765
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.984710238041025
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.982554036634617
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.96539358638643
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-16.878000000000007
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-10.930766623806782
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:13, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.960630922947452
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:14, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.96539358638642
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:14, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-20.432852435034484
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:14, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.954186491187237
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:14, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.954192299925346
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:14, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.9653738685754
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:15, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.96539358638643
# INFO:alpha_automl.automl_api:Found 107 pipelines

# %% [markdown]
# After the pipeline search is complete, we can display the leaderboard:

# %%
automl.plot_leaderboard()
# Out:
# <style type="text/css">
# </style>
# <table id="T_63528">
#   <thead>
#     <tr>
#       <th id="T_63528_level0_col0" class="col_heading level0 col0" >ranking</th>
#       <th id="T_63528_level0_col1" class="col_heading level0 col1" >pipeline</th>
#       <th id="T_63528_level0_col2" class="col_heading level0 col2" >max_error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63528_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_63528_row0_col1" class="data row0 col1" >SimpleImputer, RobustScaler, Lars</td>
#       <td id="T_63528_row0_col2" class="data row0 col2" >-10.363686</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_63528_row1_col1" class="data row1 col1" >SimpleImputer, StandardScaler, Lars</td>
#       <td id="T_63528_row1_col2" class="data row1 col2" >-10.535857</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_63528_row2_col1" class="data row2 col1" >SimpleImputer, MaxAbsScaler, Lars</td>
#       <td id="T_63528_row2_col2" class="data row2 col2" >-10.750064</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_63528_row3_col1" class="data row3 col1" >SimpleImputer, Lars</td>
#       <td id="T_63528_row3_col2" class="data row3 col2" >-10.930767</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_63528_row4_col1" class="data row4 col1" >SimpleImputer, MaxAbsScaler, LinearRegression</td>
#       <td id="T_63528_row4_col2" class="data row4 col2" >-10.982554</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_63528_row5_col1" class="data row5 col1" >SimpleImputer, StandardScaler, LinearRegression</td>
#       <td id="T_63528_row5_col2" class="data row5 col2" >-10.982554</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_63528_row6_col1" class="data row6 col1" >SimpleImputer, RobustScaler, LinearRegression</td>
#       <td id="T_63528_row6_col2" class="data row6 col2" >-10.982554</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_63528_row7_col1" class="data row7 col1" >SimpleImputer, LinearRegression</td>
#       <td id="T_63528_row7_col2" class="data row7 col2" >-10.982554</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_63528_row8_col1" class="data row8 col1" >SimpleImputer, Ridge</td>
#       <td id="T_63528_row8_col2" class="data row8 col2" >-10.984710</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_63528_row9_col1" class="data row9 col1" >SimpleImputer, RidgeCV</td>
#       <td id="T_63528_row9_col2" class="data row9 col2" >-11.003350</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_63528_row10_col1" class="data row10 col1" >SimpleImputer, StandardScaler, RidgeCV</td>
#       <td id="T_63528_row10_col2" class="data row10 col2" >-11.084285</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_63528_row11_col1" class="data row11 col1" >SimpleImputer, StandardScaler, Ridge</td>
#       <td id="T_63528_row11_col2" class="data row11 col2" >-11.084285</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_63528_row12_col1" class="data row12 col1" >SimpleImputer, MaxAbsScaler, BayesianRidge</td>
#       <td id="T_63528_row12_col2" class="data row12 col2" >-11.088161</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_63528_row13_col1" class="data row13 col1" >SimpleImputer, RobustScaler, Ridge</td>
#       <td id="T_63528_row13_col2" class="data row13 col2" >-11.227328</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_63528_row14_col1" class="data row14 col1" >SimpleImputer, RobustScaler, RidgeCV</td>
#       <td id="T_63528_row14_col2" class="data row14 col2" >-11.227328</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_63528_row15_col1" class="data row15 col1" >SimpleImputer, MaxAbsScaler, LassoCV</td>
#       <td id="T_63528_row15_col2" class="data row15 col2" >-11.486757</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_63528_row16_col1" class="data row16 col1" >SimpleImputer, StandardScaler, ARDRegression</td>
#       <td id="T_63528_row16_col2" class="data row16 col2" >-11.586823</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_63528_row17_col1" class="data row17 col1" >SimpleImputer, RobustScaler, ARDRegression</td>
#       <td id="T_63528_row17_col2" class="data row17 col2" >-11.587805</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_63528_row18_col1" class="data row18 col1" >SimpleImputer, MaxAbsScaler, ARDRegression</td>
#       <td id="T_63528_row18_col2" class="data row18 col2" >-11.590132</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_63528_row19_col1" class="data row19 col1" >SimpleImputer, MaxAbsScaler, RidgeCV</td>
#       <td id="T_63528_row19_col2" class="data row19 col2" >-11.617772</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row20_col0" class="data row20 col0" >21</td>
#       <td id="T_63528_row20_col1" class="data row20 col1" >SimpleImputer, RobustScaler, HuberRegressor</td>
#       <td id="T_63528_row20_col2" class="data row20 col2" >-12.493781</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row21_col0" class="data row21 col0" >22</td>
#       <td id="T_63528_row21_col1" class="data row21 col1" >SimpleImputer, MaxAbsScaler, HuberRegressor</td>
#       <td id="T_63528_row21_col2" class="data row21 col2" >-12.496935</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row22_col0" class="data row22 col0" >23</td>
#       <td id="T_63528_row22_col1" class="data row22 col1" >SimpleImputer, MaxAbsScaler, TheilSenRegressor</td>
#       <td id="T_63528_row22_col2" class="data row22 col2" >-12.588707</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row23_col0" class="data row23 col0" >24</td>
#       <td id="T_63528_row23_col1" class="data row23 col1" >SimpleImputer, MaxAbsScaler, RANSACRegressor</td>
#       <td id="T_63528_row23_col2" class="data row23 col2" >-12.823431</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row24_col0" class="data row24 col0" >25</td>
#       <td id="T_63528_row24_col1" class="data row24 col1" >SimpleImputer, RobustScaler, Lasso</td>
#       <td id="T_63528_row24_col2" class="data row24 col2" >-13.386757</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row25_col0" class="data row25 col0" >26</td>
#       <td id="T_63528_row25_col1" class="data row25 col1" >SimpleImputer, ARDRegression</td>
#       <td id="T_63528_row25_col2" class="data row25 col2" >-13.907023</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row26_col0" class="data row26 col0" >27</td>
#       <td id="T_63528_row26_col1" class="data row26 col1" >SimpleImputer, RobustScaler, ElasticNet</td>
#       <td id="T_63528_row26_col2" class="data row26 col2" >-14.192085</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row27_col0" class="data row27 col0" >28</td>
#       <td id="T_63528_row27_col1" class="data row27 col1" >SimpleImputer, RobustScaler, SVR</td>
#       <td id="T_63528_row27_col2" class="data row27 col2" >-14.347167</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row28_col0" class="data row28 col0" >29</td>
#       <td id="T_63528_row28_col1" class="data row28 col1" >SimpleImputer, MaxAbsScaler, PassiveAggressiveRegressor</td>
#       <td id="T_63528_row28_col2" class="data row28 col2" >-14.707122</td>
#     </tr>
#     <tr>
#       <td id="T_63528_row29_col0" class="data row29 col0" >30</td>
#       <td

# %% [markdown]
# Removing the target column from the features for the test dataset

# %%
X_test = test_dataset.drop(columns=[target_column])
X_test
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  model  origin
# 0           8           307       130.0    3504          12.0     70       1
# 1           8           304       150.0    3433          12.0     70       1
# 2           8           429       198.0    4341          10.0     70       1
# 3           8           390       190.0    3850           8.5     70       1
# 4           6           198        95.0    2833          15.5     70       1
# ..        ...           ...         ...     ...           ...    ...     ...
# 95          6           181       110.0    2945          16.4     82       1
# 96          6           232       112.0    2835          14.7     82       1
# 97          4           140        86.0    2790          15.6     82       1
# 98          4            97        52.0    2130          24.6     82       2
# 99          4           120        79.0    2625          18.6     82       1
#
# [100 rows x 7 columns]

# %% [markdown]
# Selecting the target column for the test dataset

# %%
y_test = test_dataset[[target_column]]
y_test
# Out:
#     class
# 0    18.0
# 1    16.0
# 2    15.0
# 3    15.0
# 4    22.0
# ..    ...
# 95   25.0
# 96   22.0
# 97   27.0
# 98   44.0
# 99   28.0
#
# [100 rows x 1 columns]

# %% [markdown]
# Pipeline predictions are accessed with:

# %%
y_pred = automl.predict(X_test)
y_pred
# Out:
# array([16.17594075, 16.5593719 ,  8.40615905, 12.25031677, 19.59061757,
#        25.37900055, 22.27470123,  6.83028964, 22.18710614, 25.27320556,
#        21.51490654,  8.7639713 ,  4.95537747, 18.84548957, 21.64539569,
#        27.83326706, 25.53160554, 25.89589633, 10.27116937,  9.90857079,
#        14.71282856, 13.45786287, 13.40529068, 19.03090845, 23.05481909,
#        19.49683107, 23.96098277, 27.51667104,  6.32891573, 13.05267487,
#         7.76875196, 21.59613888,  7.18102676, 27.25485452, 24.75580235,
#        25.45527664, 11.14569674, 26.36192631, 16.71799224, 22.81199429,
#        22.83549187, 13.89607338, 26.8280351 , 26.33093855, 20.36982564,
#        12.68723518, 22.8418091 , 27.7639779 , 29.700172  , 23.62110191,
#        23.42186255, 32.84132424, 28.3261874 , 33.66217693, 17.70705711,
#        26.79608139, 32.93052208, 18.85075878, 19.87289665, 15.56689456,
#        14.79151918, 23.52046125, 28.90573404, 34.14041032, 35.10682171,
#        24.67415083, 21.29016813, 23.46852583, 23.67614548, 24.95545605,
#        23.57799335, 21.46878304, 20.04078488, 34.40660557, 21.13449752,
#        27.71506504, 35.04018864, 29.16312319, 25.19198778, 29.74293182,
#        32.86988367, 29.19507678, 31.18377877, 32.66733027, 30.59744204,
#        29.29518929, 29.14980075, 29.4468897 , 26.76045387, 35.26408408,
#        36.83022921, 37.18662467, 32.69304726, 35.06188938, 36.92424314,
#        28.74252362, 29.20681355, 27.30235334, 35.43040653, 29.07402321])

# %% [markdown]
# The pipeline can be evaluated against a held out dataset with the function call:

# %%
automl.score(X_test, y_test)
# Out:
# INFO:alpha_automl.automl_api:Metric: max_error, Score: 8.569593468604381
# {'metric': 'max_error', 'score': 8.569593468604381}

# %% [markdown]
# ### Visualizing pipelines using Pipeline Profiler

# %% [markdown]
# In order to explore the produced pipelines, we can use [PipelineProfiler](https://github.com/VIDA-NYU/PipelineVis). PipelineProfiler is a visualization that enables users to compare and explore the pipelines generated by the AlphaAutoML system.
#
# After the pipeline search process is completed, we can use PipelineProfiler with:

# %%
automl.plot_comparison_pipelines()

# %% [markdown]
# For more information about how to use PipelineProfiler, click [here](https://towardsdatascience.com/exploring-auto-sklearn-models-with-pipelineprofiler-5b2c54136044). There is also a video demo available [here](https://www.youtube.com/watch?v=2WSYoaxLLJ8).
