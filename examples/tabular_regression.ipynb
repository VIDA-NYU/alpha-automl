# %% [markdown]
# ## Solving Tabular Regression Tasks

# %% [markdown]
# First, import the class `AutoMLRegressor`

# %%
from alpha_automl import AutoMLRegressor
import pandas as pd

# %% [markdown]
# ### Generating Pipelines for CSV Datasets

# %% [markdown]
# In this example, we are generating pipelines for a CSV dataset. The 196_autoMpg dataset is used for this example.

# %%
output_path = 'tmp/'
train_dataset = pd.read_csv('datasets/196_autoMpg/train_data.csv')
test_dataset = pd.read_csv('datasets/196_autoMpg/test_data.csv')

# %% [markdown]
# Removing the target column from the features for the train dataset

# %%
target_column = 'class'
X_train = train_dataset.drop(columns=[target_column])
X_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model  origin
# 0            8         350.0       165.0    3693          11.5     70       1
# 1            8         318.0       150.0    3436          11.0     70       1
# 2            8         302.0       140.0    3449          10.5     70       1
# 3            8         454.0       220.0    4354           9.0     70       1
# 4            8         440.0       215.0    4312           8.5     70       1
# ..         ...           ...         ...     ...           ...    ...     ...
# 293          4         144.0        96.0    2665          13.9     82       3
# 294          4         135.0        84.0    2370          13.0     82       1
# 295          4         151.0        90.0    2950          17.3     82       1
# 296          4         135.0        84.0    2295          11.6     82       1
# 297          4         119.0        82.0    2720          19.4     82       1
#
# [298 rows x 7 columns]

# %% [markdown]
# Selecting the target column for the train dataset

# %%
y_train = train_dataset[[target_column]]
y_train
# Out:
#      class
# 0     15.0
# 1     18.0
# 2     17.0
# 3     14.0
# 4     14.0
# ..     ...
# 293   32.0
# 294   36.0
# 295   27.0
# 296   32.0
# 297   31.0
#
# [298 rows x 1 columns]

# %% [markdown]
# ### Searching  Pipelines

# %%
automl = AutoMLRegressor(output_path, time_bound=10)
automl.fit(X_train, y_train)
# Out:
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3182052729132256
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:00, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3182052729132256
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8462896066896053
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8483592673992657
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.848401895838938
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.773362899435579
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:01, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.8657199999999996
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8582362267362256
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8367902678861108
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8263369072040807
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.8821333333333337
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8227864883264866
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3215148620878994
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.781521416212688
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7990043546359473
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.813484476725261
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3399372518036574
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.9781333333333335
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.513216874223524
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=5.387718990604761
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.980588889572973
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3174927666688006
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.347018924201971
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.320064448003014
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.786475050875051
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.752444108121714
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=4.3179807643962915
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3225600839490532
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.939598729451497
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3182052729132256
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3174927666688014
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=6.48021332353106
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.361280495774604
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.6542138049431747
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.8684666666666663
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3215148620878994
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7990043546359473
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3334535489321673
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.813484476725261
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.9781333333333335
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.342870174404789
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=5.387718990604761
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3754850771308056
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.980588889572973
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3174927666688006
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.320064448003014
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3387513579047527
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.786475050875051
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.31820527288295
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.752444108121714
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=4.317980764396291
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3225600839490532
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.939598729451497
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3182052729132256
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3182052729123734
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3174927666688014
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=6.48021332353106
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.361280495774604
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.6505917423335315
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.390991159716147
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.318204903584579
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.060400756557959
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:08, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.3381018981933592
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8325720173050315
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.6681224152336087
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.5551999999999997
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8635332793132777
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.88612
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=5.387718990604761
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.807195987501205
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:09, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7042504499847966
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.736460416606205
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.855127060717059
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.6358713146555934
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.458666666666667
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.197670510923085
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.4127727595784236
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.651745516791316
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=9.669861549417176
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:10, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.859437400007399
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:11, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.6821484392592128
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:11, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.845410254190253
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:11, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7391438045782044
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:11, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=6.03664133571309
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:11, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.860813799065362
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:11, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.8840933333333343
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:11, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3215148620879
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.31820527288295
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.9013866666666657
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3182052729123734
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:12, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.318204903584579
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:28, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.9565333333333332
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:29, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7990043546359473
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:30, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7990043546359473
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:30, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7349562886555994
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:30, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.9565333333333332
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:30, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.6089890491704395
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:30, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.4565974522345853
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:30, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.4421053430164883
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:31, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.4649985629248206
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:31, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3174927666688006
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:31, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.449917781147812
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:33, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.970666666666667
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:35, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.752444108121714
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:38, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.838621668756028
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:41, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.4421053430164883
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:42, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.9805888895729726
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:42, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.9805888895729726
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:45, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8049883829024194
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:46, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.834703791794434
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:46, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.970666666666667
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:46, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3182348943353595
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:47, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.786475050875051
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:47, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.8147953323355974
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:50, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7990043546359473
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:50, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7349562886555994
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:51, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.318759511671355
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:52, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3215148620879
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:53, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3215148620879
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:54, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7990043546359473
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:54, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3215148620879
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:55, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.6024828738634436
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:55, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.5937412229587244
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:55, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7349562886555994
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:55, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3215148620879
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:59, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.970666666666667
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:59, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.0549307009322355
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.654304828899436
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.6702783883146557
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.8495200000000003
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7990043546359473
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:06, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7349562886555994
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:07, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.128266666666667
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:11, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3105221337599398
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:14, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.569436839870976
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:15, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3215148620879
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:15, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.673222572932995
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:15, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.7990043546359473
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:23, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=1.8975999999999995
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:26, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.3561551001289587
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:39, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.6402069497290195
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:40, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.569436839870976
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:40, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=3.4035889780017574
# INFO:alpha_automl.automl_api:Found pipeline, time=0:01:44, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=2.0482357325917957
# INFO:alpha_automl.automl_api:Found 144 pipelines

# %% [markdown]
# ### Exploring Pipelines

# %% [markdown]
# After the pipeline search is complete, we can display the leaderboard:

# %%
automl.plot_leaderboard()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8863">
#   <thead>
#     <tr>
#       <th id="T_d8863_level0_col0" class="col_heading level0 col0" >ranking</th>
#       <th id="T_d8863_level0_col1" class="col_heading level0 col1" >pipeline</th>
#       <th id="T_d8863_level0_col2" class="col_heading level0 col2" >mean_absolute_error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d8863_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d8863_row0_col1" class="data row0 col1" >SimpleImputer, RobustScaler, RandomForestRegressor</td>
#       <td id="T_d8863_row0_col2" class="data row0 col2" >1.850</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d8863_row1_col1" class="data row1 col1" >SimpleImputer, StandardScaler, RandomForestRegressor</td>
#       <td id="T_d8863_row1_col2" class="data row1 col2" >1.866</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d8863_row2_col1" class="data row2 col1" >SimpleImputer, MaxAbsScaler, ExtraTreesRegressor</td>
#       <td id="T_d8863_row2_col2" class="data row2 col2" >1.868</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d8863_row3_col1" class="data row3 col1" >SimpleImputer, MaxAbsScaler, RandomForestRegressor</td>
#       <td id="T_d8863_row3_col2" class="data row3 col2" >1.882</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_d8863_row4_col1" class="data row4 col1" >SimpleImputer, RobustScaler, ExtraTreesRegressor</td>
#       <td id="T_d8863_row4_col2" class="data row4 col2" >1.884</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_d8863_row5_col1" class="data row5 col1" >SimpleImputer, StandardScaler, ExtraTreesRegressor</td>
#       <td id="T_d8863_row5_col2" class="data row5 col2" >1.886</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_d8863_row6_col1" class="data row6 col1" >SimpleImputer, RandomForestRegressor</td>
#       <td id="T_d8863_row6_col2" class="data row6 col2" >1.898</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_d8863_row7_col1" class="data row7 col1" >SimpleImputer, ExtraTreesRegressor</td>
#       <td id="T_d8863_row7_col2" class="data row7 col2" >1.901</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_d8863_row8_col1" class="data row8 col1" >SimpleImputer, RobustScaler, GradientBoostingRegressor</td>
#       <td id="T_d8863_row8_col2" class="data row8 col2" >2.048</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_d8863_row9_col1" class="data row9 col1" >SimpleImputer, StandardScaler, GradientBoostingRegressor</td>
#       <td id="T_d8863_row9_col2" class="data row9 col2" >2.055</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_d8863_row10_col1" class="data row10 col1" >SimpleImputer, MaxAbsScaler, GradientBoostingRegressor</td>
#       <td id="T_d8863_row10_col2" class="data row10 col2" >2.060</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_d8863_row11_col1" class="data row11 col1" >SimpleImputer, StandardScaler, KNeighborsRegressor</td>
#       <td id="T_d8863_row11_col2" class="data row11 col2" >2.128</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_d8863_row12_col1" class="data row12 col1" >SimpleImputer, MaxAbsScaler, LGBMRegressor</td>
#       <td id="T_d8863_row12_col2" class="data row12 col2" >2.198</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_d8863_row13_col1" class="data row13 col1" >SimpleImputer, MaxAbsScaler, XGBRegressor</td>
#       <td id="T_d8863_row13_col2" class="data row13 col2" >2.338</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_d8863_row14_col1" class="data row14 col1" >SimpleImputer, MaxAbsScaler, DecisionTreeRegressor</td>
#       <td id="T_d8863_row14_col2" class="data row14 col2" >2.459</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_d8863_row15_col1" class="data row15 col1" >SimpleImputer, MaxAbsScaler, KNeighborsRegressor</td>
#       <td id="T_d8863_row15_col2" class="data row15 col2" >2.555</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_d8863_row16_col1" class="data row16 col1" >SimpleImputer, MaxAbsScaler, RidgeCV</td>
#       <td id="T_d8863_row16_col2" class="data row16 col2" >2.636</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_d8863_row17_col1" class="data row17 col1" >SimpleImputer, StandardScaler, RANSACRegressor</td>
#       <td id="T_d8863_row17_col2" class="data row17 col2" >2.640</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_d8863_row18_col1" class="data row18 col1" >SimpleImputer, MaxAbsScaler, LassoCV</td>
#       <td id="T_d8863_row18_col2" class="data row18 col2" >2.651</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_d8863_row19_col1" class="data row19 col1" >SimpleImputer, MaxAbsScaler, HuberRegressor</td>
#       <td id="T_d8863_row19_col2" class="data row19 col2" >2.652</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row20_col0" class="data row20 col0" >21</td>
#       <td id="T_d8863_row20_col1" class="data row20 col1" >SimpleImputer, MaxAbsScaler, ARDRegression</td>
#       <td id="T_d8863_row20_col2" class="data row20 col2" >2.654</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row21_col0" class="data row21 col0" >22</td>
#       <td id="T_d8863_row21_col1" class="data row21 col1" >SimpleImputer, StandardScaler, ARDRegression</td>
#       <td id="T_d8863_row21_col2" class="data row21 col2" >2.654</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row22_col0" class="data row22 col0" >23</td>
#       <td id="T_d8863_row22_col1" class="data row22 col1" >SimpleImputer, MaxAbsScaler, PassiveAggressiveRegressor</td>
#       <td id="T_d8863_row22_col2" class="data row22 col2" >2.668</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row23_col0" class="data row23 col0" >24</td>
#       <td id="T_d8863_row23_col1" class="data row23 col1" >SimpleImputer, StandardScaler, LassoCV</td>
#       <td id="T_d8863_row23_col2" class="data row23 col2" >2.670</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row24_col0" class="data row24 col0" >25</td>
#       <td id="T_d8863_row24_col1" class="data row24 col1" >SimpleImputer, RobustScaler, LassoCV</td>
#       <td id="T_d8863_row24_col2" class="data row24 col2" >2.673</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row25_col0" class="data row25 col0" >26</td>
#       <td id="T_d8863_row25_col1" class="data row25 col1" >SimpleImputer, MaxAbsScaler, BayesianRidge</td>
#       <td id="T_d8863_row25_col2" class="data row25 col2" >2.682</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row26_col0" class="data row26 col0" >27</td>
#       <td id="T_d8863_row26_col1" class="data row26 col1" >SimpleImputer, MaxAbsScaler, LinearRegression</td>
#       <td id="T_d8863_row26_col2" class="data row26 col2" >2.704</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row27_col0" class="data row27 col0" >28</td>
#       <td id="T_d8863_row27_col1" class="data row27 col1" >SimpleImputer, StandardScaler, SelectPercentile, XGBRegressor</td>
#       <td id="T_d8863_row27_col2" class="data row27 col2" >2.735</td>
#     </tr>
#     <tr>
#       <td id="T_d8863_row28_col0" class="data row28 col0" >29</td>
#       <td id="T_d8863_row28_col1" class="data row28 col1" >SimpleImputer, RobustScaler, SelectPercentile, XGBRegressor</td>
#       <td id="T_d8863_row28_col2"

# %% [markdown]
# In order to explore the produced pipelines, we can use [PipelineProfiler](https://github.com/VIDA-NYU/PipelineVis). PipelineProfiler is a visualization that enables users to compare and explore the pipelines generated by the AlphaAutoML system.
#
# After the pipeline search process is completed, we can use PipelineProfiler with:

# %%
automl.plot_comparison_pipelines()

# %% [markdown]
# For more information about how to use PipelineProfiler, click [here](https://towardsdatascience.com/exploring-auto-sklearn-models-with-pipelineprofiler-5b2c54136044). There is also a video demo available [here](https://www.youtube.com/watch?v=2WSYoaxLLJ8).

# %% [markdown]
# ### Testing Pipelines

# %% [markdown]
# Removing the target column from the features for the test dataset

# %%
X_test = test_dataset.drop(columns=[target_column])
X_test
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  model  origin
# 0           8           307       130.0    3504          12.0     70       1
# 1           8           304       150.0    3433          12.0     70       1
# 2           8           429       198.0    4341          10.0     70       1
# 3           8           390       190.0    3850           8.5     70       1
# 4           6           198        95.0    2833          15.5     70       1
# ..        ...           ...         ...     ...           ...    ...     ...
# 95          6           181       110.0    2945          16.4     82       1
# 96          6           232       112.0    2835          14.7     82       1
# 97          4           140        86.0    2790          15.6     82       1
# 98          4            97        52.0    2130          24.6     82       2
# 99          4           120        79.0    2625          18.6     82       1
#
# [100 rows x 7 columns]

# %% [markdown]
# Selecting the target column for the test dataset

# %%
y_test = test_dataset[[target_column]]
y_test
# Out:
#     class
# 0    18.0
# 1    16.0
# 2    15.0
# 3    15.0
# 4    22.0
# ..    ...
# 95   25.0
# 96   22.0
# 97   27.0
# 98   44.0
# 99   28.0
#
# [100 rows x 1 columns]

# %% [markdown]
# Pipeline predictions are accessed with:

# %%
y_pred = automl.predict(X_test)
y_pred
# Out:
# array([16.006, 16.881, 13.73 , 13.815, 18.974, 26.6  , 23.967, 11.46 ,
#        23.847, 25.053, 19.981, 13.03 , 12.285, 18.766, 22.43 , 27.748,
#        27.225, 24.734, 12.96 , 12.28 , 14.775, 14.535, 14.42 , 20.725,
#        23.575, 20.497, 22.571, 26.035, 11.79 , 14.43 , 11.85 , 18.834,
#        12.51 , 25.03 , 22.33 , 25.337, 13.405, 26.015, 14.26 , 19.364,
#        24.946, 14.309, 25.82 , 26.168, 19.517, 14.305, 24.234, 26.525,
#        28.47 , 23.815, 22.852, 30.166, 27.431, 30.246, 14.808, 21.247,
#        30.495, 18.14 , 18.818, 15.379, 15.288, 24.687, 28.594, 37.447,
#        35.187, 20.838, 19.92 , 18.72 , 23.022, 19.548, 20.977, 17.521,
#        16.644, 34.246, 19.123, 26.632, 38.061, 29.279, 26.114, 36.044,
#        32.836, 26.38 , 35.321, 35.247, 36.533, 29.394, 29.787, 29.829,
#        26.586, 34.518, 36.513, 35.733, 36.856, 35.577, 33.981, 28.263,
#        29.105, 26.971, 40.338, 29.909])

# %% [markdown]
# The pipeline can be evaluated against a held out dataset with the function call:

# %%
automl.score(X_test, y_test)
# Out:
# INFO:alpha_automl.automl_api:Metric: mean_absolute_error, Score: 1.7378600000000004
# {'metric': 'mean_absolute_error', 'score': 1.7378600000000004}
