# %% [markdown]
# ## Solving Tabular Regression Tasks

# %% [markdown]
# First, import the class `AutoMLRegressor`

# %%
from alpha_automl  import AutoMLRegressor
import pandas as pd

# %% [markdown]
# ### Generating Pipelines for CSV Datasets

# %% [markdown]
# In this example, we are generating pipelines for a CSV dataset. The 196_autoMpg dataset is used for this example.

# %%
output_path = '/Users/rlopez/D3M/tmp/'
train_dataset = pd.read_csv('/Users/rlopez/D3M/examples/datasets/196_autoMpg/train_data.csv')
test_dataset = pd.read_csv('/Users/rlopez/D3M/examples/datasets/196_autoMpg/test_data.csv')

# %% [markdown]
# Removing the target column from the features for the train dataset

# %%
X_train = train_dataset.drop(columns=['class'])
X_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model  origin
# 0            8         350.0       165.0    3693          11.5     70       1
# 1            8         318.0       150.0    3436          11.0     70       1
# 2            8         302.0       140.0    3449          10.5     70       1
# 3            8         454.0       220.0    4354           9.0     70       1
# 4            8         440.0       215.0    4312           8.5     70       1
# ..         ...           ...         ...     ...           ...    ...     ...
# 293          4         144.0        96.0    2665          13.9     82       3
# 294          4         135.0        84.0    2370          13.0     82       1
# 295          4         151.0        90.0    2950          17.3     82       1
# 296          4         135.0        84.0    2295          11.6     82       1
# 297          4         119.0        82.0    2720          19.4     82       1
#
# [298 rows x 7 columns]

# %% [markdown]
# Selecting the target column for the train dataset

# %%
y_train = train_dataset[['class']]
y_train
# Out:
#      class
# 0     15.0
# 1     18.0
# 2     17.0
# 3     14.0
# 4     14.0
# ..     ...
# 293   32.0
# 294   36.0
# 295   27.0
# 296   32.0
# 297   31.0
#
# [298 rows x 1 columns]

# %% [markdown]
# ### Searching  Pipelines

# %%
automl = AutoMLRegressor(output_path, time_bound=10)
automl.fit(X_train, y_train)
# Out:
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.548409932589315
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.708540608138133
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-12.080522883240945
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.708540608138133
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.463559556336683
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.491872393245075
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.714207441820857
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.715013617742809
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.715013617742816
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:02, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-16.699714478831538
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.22033333333337
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.689053302151649
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-21.374000000000045
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-15.03387084514771
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-15.173433877136095
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-15.940000000000001
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-20.422330642525147
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-15.394147305109588
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-24.4
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-20.00370004512676
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.463705667732633
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.714614747622829
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.722079949119223
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-21.405685773867592
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-16.18524932861328
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.71420744182085
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:03, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-13.877684049780306
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.627414289607387
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.463559556336676
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.222741184037545
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.715013617742809
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.549549355793275
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.231000000000012
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-14.863616277954002
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-17.90900000000001
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-12.979345075421065
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-13.019221144444202
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-11.46355955633669
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-18.48
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:04, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-19.610795626568464
# INFO:alpha_automl.automl_api:Found pipeline, time=0:00:05, scoring...
# INFO:alpha_automl.automl_api:Scored pipeline, score=-13.053319597992566
# INFO:alpha_automl.automl_api:Found 41 pipelines

# %% [markdown]
# After the pipeline search is complete, we can display the leaderboard:

# %%
automl.plot_leaderboard()
# Out:
# <style type="text/css">
# </style>
# <table id="T_84931">
#   <thead>
#     <tr>
#       <th id="T_84931_level0_col0" class="col_heading level0 col0" >ranking</th>
#       <th id="T_84931_level0_col1" class="col_heading level0 col1" >summary</th>
#       <th id="T_84931_level0_col2" class="col_heading level0 col2" >max_error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84931_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_84931_row0_col1" class="data row0 col1" >SimpleImputer, MaxAbsScaler, Lars</td>
#       <td id="T_84931_row0_col2" class="data row0 col2" >-11.222741</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_84931_row1_col1" class="data row1 col1" >SimpleImputer, MaxAbsScaler, LinearRegression</td>
#       <td id="T_84931_row1_col2" class="data row1 col2" >-11.463560</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_84931_row2_col1" class="data row2 col1" >SimpleImputer, StandardScaler, LinearRegression</td>
#       <td id="T_84931_row2_col2" class="data row2 col2" >-11.463560</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_84931_row3_col1" class="data row3 col1" >SimpleImputer, RobustScaler, LinearRegression</td>
#       <td id="T_84931_row3_col2" class="data row3 col2" >-11.463560</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_84931_row4_col1" class="data row4 col1" >SimpleImputer, StandardScaler, RidgeCV</td>
#       <td id="T_84931_row4_col2" class="data row4 col2" >-11.548410</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_84931_row5_col1" class="data row5 col1" >SimpleImputer, MaxAbsScaler, ARDRegression</td>
#       <td id="T_84931_row5_col2" class="data row5 col2" >-11.627414</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_84931_row6_col1" class="data row6 col1" >SimpleImputer, MaxAbsScaler, RidgeCV</td>
#       <td id="T_84931_row6_col2" class="data row6 col2" >-12.080523</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_84931_row7_col1" class="data row7 col1" >SimpleImputer, MaxAbsScaler, PassiveAggressiveRegressor</td>
#       <td id="T_84931_row7_col2" class="data row7 col2" >-12.979345</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_84931_row8_col1" class="data row8 col1" >SimpleImputer, MaxAbsScaler, HuberRegressor</td>
#       <td id="T_84931_row8_col2" class="data row8 col2" >-13.019221</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_84931_row9_col1" class="data row9 col1" >SimpleImputer, MaxAbsScaler, TheilSenRegressor</td>
#       <td id="T_84931_row9_col2" class="data row9 col2" >-13.053320</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_84931_row10_col1" class="data row10 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, RANSACRegressor</td>
#       <td id="T_84931_row10_col2" class="data row10 col2" >-13.877684</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_84931_row11_col1" class="data row11 col1" >SimpleImputer, RobustScaler, SVR</td>
#       <td id="T_84931_row11_col2" class="data row11 col2" >-14.491872</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_84931_row12_col1" class="data row12 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, Ridge</td>
#       <td id="T_84931_row12_col2" class="data row12 col2" >-14.689053</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_84931_row13_col1" class="data row13 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, RidgeCV</td>
#       <td id="T_84931_row13_col2" class="data row13 col2" >-14.708541</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_84931_row14_col1" class="data row14 col1" >SimpleImputer, MaxAbsScaler, SelectPercentile, RidgeCV</td>
#       <td id="T_84931_row14_col2" class="data row14 col2" >-14.708541</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_84931_row15_col1" class="data row15 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, BayesianRidge</td>
#       <td id="T_84931_row15_col2" class="data row15 col2" >-14.714207</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_84931_row16_col1" class="data row16 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, ARDRegression</td>
#       <td id="T_84931_row16_col2" class="data row16 col2" >-14.714207</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_84931_row17_col1" class="data row17 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, LassoCV</td>
#       <td id="T_84931_row17_col2" class="data row17 col2" >-14.714615</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_84931_row18_col1" class="data row18 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, LinearRegression</td>
#       <td id="T_84931_row18_col2" class="data row18 col2" >-14.715014</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_84931_row19_col1" class="data row19 col1" >SimpleImputer, MaxAbsScaler, SelectPercentile, LinearRegression</td>
#       <td id="T_84931_row19_col2" class="data row19 col2" >-14.715014</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row20_col0" class="data row20 col0" >21</td>
#       <td id="T_84931_row20_col1" class="data row20 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, Lars</td>
#       <td id="T_84931_row20_col2" class="data row20 col2" >-14.715014</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row21_col0" class="data row21 col0" >22</td>
#       <td id="T_84931_row21_col1" class="data row21 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, SGDRegressor</td>
#       <td id="T_84931_row21_col2" class="data row21 col2" >-14.722080</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row22_col0" class="data row22 col0" >23</td>
#       <td id="T_84931_row22_col1" class="data row22 col1" >SimpleImputer, MaxAbsScaler, Ridge</td>
#       <td id="T_84931_row22_col2" class="data row22 col2" >-14.863616</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row23_col0" class="data row23 col0" >24</td>
#       <td id="T_84931_row23_col1" class="data row23 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, PassiveAggressiveRegressor</td>
#       <td id="T_84931_row23_col2" class="data row23 col2" >-15.033871</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row24_col0" class="data row24 col0" >25</td>
#       <td id="T_84931_row24_col1" class="data row24 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, HuberRegressor</td>
#       <td id="T_84931_row24_col2" class="data row24 col2" >-15.173434</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row25_col0" class="data row25 col0" >26</td>
#       <td id="T_84931_row25_col1" class="data row25 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, TheilSenRegressor</td>
#       <td id="T_84931_row25_col2" class="data row25 col2" >-15.394147</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row26_col0" class="data row26 col0" >27</td>
#       <td id="T_84931_row26_col1" class="data row26 col1" >SimpleImputer, MaxAbsScaler, GenericUnivariateSelect, KNeighborsRegressor</td>
#       <td id="T_84931_row26_col2" class="data row26 col2" >-15.940000</td>
#     </tr>
#     <tr>
#       <td id="T_84931_row27_col0" class="data row27 col0" >28</td>
#       <td id="T_84931_row27_col1" class="data row27 col1" >

# %% [markdown]
# Removing the target column from the features for the test dataset

# %%
X_test = test_dataset.drop(columns=['class'])
X_test
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  model  origin
# 0           8           307       130.0    3504          12.0     70       1
# 1           8           304       150.0    3433          12.0     70       1
# 2           8           429       198.0    4341          10.0     70       1
# 3           8           390       190.0    3850           8.5     70       1
# 4           6           198        95.0    2833          15.5     70       1
# ..        ...           ...         ...     ...           ...    ...     ...
# 95          6           181       110.0    2945          16.4     82       1
# 96          6           232       112.0    2835          14.7     82       1
# 97          4           140        86.0    2790          15.6     82       1
# 98          4            97        52.0    2130          24.6     82       2
# 99          4           120        79.0    2625          18.6     82       1
#
# [100 rows x 7 columns]

# %% [markdown]
# Selecting the target column for the test dataset

# %%
y_test = test_dataset[['class']]
y_test
# Out:
#     class
# 0    18.0
# 1    16.0
# 2    15.0
# 3    15.0
# 4    22.0
# ..    ...
# 95   25.0
# 96   22.0
# 97   27.0
# 98   44.0
# 99   28.0
#
# [100 rows x 1 columns]

# %% [markdown]
# Pipeline predictions are accessed with:

# %%
y_pred = automl.predict(X_test)
y_pred
# Out:
# array([14.08142539, 13.85865698, 12.29690254, 14.05646111, 17.66295652,
#        24.73077502, 21.16589936,  5.54482198, 23.13437337, 25.54645937,
#        21.96006082, 11.24752756,  5.82209153, 20.56797595, 22.93415109,
#        27.55726534, 23.93092069, 26.23409822, 12.90464557, 12.17674539,
#        11.85104829, 11.11803549, 11.36098008, 18.40272393, 23.59795392,
#        19.39107422, 24.54403185, 27.08405218, 10.04304236, 10.98174645,
#        11.98663973, 19.88041871,  9.70423376, 26.80221186, 20.1810553 ,
#        24.37842419, 12.66069436, 26.91407252, 16.49343766, 21.04234553,
#        24.19524186, 10.96844655, 26.04201085, 26.88902146, 20.37126107,
#        10.59633736, 24.03331731, 26.79954045, 28.94407867, 23.42044126,
#        23.16749291, 33.30189166, 27.71775068, 34.20812229, 16.10132785,
#        23.44139647, 32.01441478, 14.32894416, 21.19521185, 18.63063606,
#        17.56029548, 25.42300381, 27.8593681 , 33.89073162, 35.65145164,
#        20.7160088 , 23.07435433, 21.65879452, 25.6652809 , 21.05957431,
#        23.87768538, 19.80474045, 21.50816764, 34.44639578, 22.5782263 ,
#        24.50284831, 35.14626457, 31.39511329, 27.23928927, 30.71047718,
#        34.02982023, 26.2484944 , 31.29615404, 32.40360985, 30.13268721,
#        29.15181998, 29.06214842, 30.95904846, 28.17782658, 36.00869699,
#        37.38986355, 37.78069633, 32.95624769, 36.97048262, 37.51806637,
#        26.295412  , 30.19703298, 28.90412499, 36.12702822, 29.64781464])

# %% [markdown]
# The pipeline can be evaluated against a held out dataset with the function call:

# %%
automl.score(X_test, y_test)
# Out:
# INFO:alpha_automl.automl_api:Metric: max_error, Score: 8.197032975604646
# {'metric': 'max_error', 'score': 8.197032975604646}

# %% [markdown]
# ### Visualizing pipelines using Pipeline Profiler

# %% [markdown]
# In order to explore the produced pipelines, we can use [PipelineProfiler](https://github.com/VIDA-NYU/PipelineVis). PipelineProfiler is a visualization that enables users to compare and explore the pipelines generated by the AlphaAutoML system.
#
# After the pipeline search process is completed, we can use PipelineProfiler with:

# %%
automl.plot_comparison_pipelines()

# %% [markdown]
# For more information about how to use PipelineProfiler, click [here](https://towardsdatascience.com/exploring-auto-sklearn-models-with-pipelineprofiler-5b2c54136044). There is also a video demo available [here](https://www.youtube.com/watch?v=2WSYoaxLLJ8).
